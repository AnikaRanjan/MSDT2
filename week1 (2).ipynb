# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ### **All exercises will be using your chosen dataset**

# %% [markdown]
# ## Step 1: Import your dataset using the tutorial from the slides

# %% [markdown]
# ## Step 2: Install necessary libraries. We are using Pandas and NumPy for week 1

# %%
# !pip install pandas numpy
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Exercises
#
# ### Pandas and NumPy Docs for Reference
#
# #### [Pandas Documentation](https://pandas.pydata.org/docs/)
#
# #### [NumPy Documentation](https://numpy.org/devdocs/)

# %% [markdown]
# ## Pandas

# %% [markdown]
# ### Exercise 1: Previewing The Dataset

# %%
# TODO: Read dataset into a Pandas dataframe
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Sleep_health_and_lifestyle_dataset.csv')
# Out:
# Mounted at /content/drive

# %%
# TODO: print the first 7 rows
df.head(7)
# Out:
#    Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0   27     Software Engineer             6.1                 6
# 1   28                Doctor             6.2                 6
# 2   28                Doctor             6.2                 6
# 3   28  Sales Representative             5.9                 4
# 4   28  Sales Representative             5.9                 4
# 5   28     Software Engineer             5.9                 4
# 6   29               Teacher             6.3                 6
#
#    Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 0                       42             6   Overweight         126/83
# 1                       60             8       Normal         125/80
# 2                       60             8       Normal         125/80
# 3                       30             8        Obese         140/90
# 4                       30             8        Obese         140/90
# 5                       30             8        Obese         140/90
# 6                       40             7        Obese         140/90
#
#    Heart Rate  Daily Steps Sleep Disorder
# 0          77         4200            NaN
# 1          75        10000            NaN
# 2          75        10000            NaN
# 3          85         3000    Sleep Apnea
# 4          85         3000    Sleep Apnea
# 5          85         3000       Insomnia
# 6          82         3500       Insomnia

# %%
# TODO: print the last 5 rows
df.tail(5)
# Out:
#      Age Occupation  Sleep Duration  Quality of Sleep  \
# 369   59      Nurse             8.1                 9
# 370   59      Nurse             8.0                 9
# 371   59      Nurse             8.1                 9
# 372   59      Nurse             8.1                 9
# 373   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
# 373                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 369          68         7000    Sleep Apnea
# 370          68         7000    Sleep Apnea
# 371          68         7000    Sleep Apnea
# 372          68         7000    Sleep Apnea
# 373          68         7000    Sleep Apnea

# %%
# TODO: print 5 random rows
df.sample(5)
# Out:
#      Age Occupation  Sleep Duration  Quality of Sleep  \
# 32    31      Nurse             7.9                 8
# 86    35   Engineer             7.2                 8
# 186   43    Teacher             6.7                 7
# 68    33  Scientist             6.2                 6
# 185   42    Teacher             6.8                 6
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# 32                        75             4  Normal Weight         117/76
# 86                        60             4         Normal         125/80
# 186                       45             4     Overweight         135/90
# 68                        50             6     Overweight         128/85
# 185                       45             7     Overweight         130/85
#
#      Heart Rate  Daily Steps Sleep Disorder
# 32           69         6800            NaN
# 86           65         5000            NaN
# 186          65         6000       Insomnia
# 68           76         5500            NaN
# 185          78         5000    Sleep Apnea

# %% [markdown]
# Write what each row and what each column represents:

# %% [markdown]
# ### Exercise 2: Examining features/shape

# %%
# TODO: Print dataset shape
df.shape
# Out:
# (374, 11)

# %%
# TODO: Print the names of the columns
df.columns
# Out:
# Index(['Age', 'Occupation', 'Sleep Duration', 'Quality of Sleep',
#        'Physical Activity Level', 'Stress Level', 'BMI Category',
#        'Blood Pressure', 'Heart Rate', 'Daily Steps', 'Sleep Disorder'],
#       dtype='object')

# %%
# TODO: Drop any identifier columns like names, id, etc...

# %%
# TODO: Print all the data types of the columns
df.dtypes
# Out:
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %%
# TODO: Find the counts of each data type
df.dtypes.value_counts()
# Out:
# int64      6
# object     4
# float64    1
# Name: count, dtype: int64

# %% [markdown]
# ### Exercise 3: Missing/Duplicate Values

# %%
# TODO: Find the number of missing values per column
df.isna().sum()
# Out:
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
# TODO: identify the column with the most missing values
df.isna().sum().idxmax()
# Out:
# 'Sleep Disorder'

# %%
# TODO: Either drop the rows with missing values or impute them
df.dropna()
# Out:
#      Age            Occupation  Sleep Duration  Quality of Sleep  \
# 3     28  Sales Representative             5.9                 4
# 4     28  Sales Representative             5.9                 4
# 5     28     Software Engineer             5.9                 4
# 6     29               Teacher             6.3                 6
# 16    29                 Nurse             6.5                 5
# ..   ...                   ...             ...               ...
# 369   59                 Nurse             8.1                 9
# 370   59                 Nurse             8.0                 9
# 371   59                 Nurse             8.1                 9
# 372   59                 Nurse             8.1                 9
# 373   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# 3                         30             8          Obese         140/90
# 4                         30             8          Obese         140/90
# 5                         30             8          Obese         140/90
# 6                         40             7          Obese         140/90
# 16                        40             7  Normal Weight         132/87
# ..                       ...           ...            ...            ...
# 369                       75             3     Overweight         140/95
# 370                       75             3     Overweight         140/95
# 371                       75             3     Overweight         140/95
# 372                       75             3     Overweight         140/95
# 373                       75             3     Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 3            85         3000    Sleep Apnea
# 4            85         3000    Sleep Apnea
# 5            85         3000       Insomnia
# 6            82         3500       Insomnia
# 16           80         4000    Sleep Apnea
# ..          ...          ...            ...
# 369          68         7000    Sleep Apnea
# 370          68         7000    Sleep Apnea
# 371          68         7000    Sleep Apnea
# 372          68         7000    Sleep Apnea
# 373          68         7000    Sleep Apnea
#
# [155 rows x 11 columns]

# %%
# TODO: Drop duplicate rows if there are any
df.drop_duplicates()
# Out:
#      Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0     27     Software Engineer             6.1                 6
# 1     28                Doctor             6.2                 6
# 3     28  Sales Representative             5.9                 4
# 5     28     Software Engineer             5.9                 4
# 6     29               Teacher             6.3                 6
# ..   ...                   ...             ...               ...
# 358   59                 Nurse             8.0                 9
# 359   59                 Nurse             8.1                 9
# 360   59                 Nurse             8.2                 9
# 364   59                 Nurse             8.0                 9
# 366   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 0                         42             6   Overweight         126/83
# 1                         60             8       Normal         125/80
# 3                         30             8        Obese         140/90
# 5                         30             8        Obese         140/90
# 6                         40             7        Obese         140/90
# ..                       ...           ...          ...            ...
# 358                       75             3   Overweight         140/95
# 359                       75             3   Overweight         140/95
# 360                       75             3   Overweight         140/95
# 364                       75             3   Overweight         140/95
# 366                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 0            77         4200            NaN
# 1            75        10000            NaN
# 3            85         3000    Sleep Apnea
# 5            85         3000       Insomnia
# 6            82         3500       Insomnia
# ..          ...          ...            ...
# 358          68         7000            NaN
# 359          68         7000            NaN
# 360          68         7000    Sleep Apnea
# 364          68         7000    Sleep Apnea
# 366          68         7000    Sleep Apnea
#
# [132 rows x 11 columns]

# %% [markdown]
# ### Exercise 4: Statistics

# %%
# TODO: Choose one numeric column and store its name in a variable
QSleep = 'Quality of Sleep'

# %%
# TODO: print a summary of statistics using .describe() for that column
df[QSleep].describe()
# Out:
# count    374.000000
# mean       7.312834
# std        1.196956
# min        4.000000
# 25%        6.000000
# 50%        7.000000
# 75%        8.000000
# max        9.000000
# Name: Quality of Sleep, dtype: float64

# %%
# TODO: Compare the mean and median of the column
df[QSleep].mean()
df[QSleep].median()
# Out:
# 7.0

# %% [markdown]
# What can the mean and median of this column tell you about the distribution of data?

# %% [markdown]
# ### Exercise 5: Filtering/GroupBy

# %%
# TODO: From any of the columns, look for suspicious values
# (like negative numbers)
df[df[QSleep] < 0]
# Out:
# Empty DataFrame
# Columns: [Age, Occupation, Sleep Duration, Quality of Sleep, Physical Activity Level, Stress Level, BMI Category, Blood Pressure, Heart Rate, Daily Steps, Sleep Disorder]
# Index: []

# %%
# TODO: From any categorical column, create and display a dataset that only
# contains one of the categories
df[df['Quality of Sleep'] == '']
# Out:
# Empty DataFrame
# Columns: [Age, Occupation, Sleep Duration, Quality of Sleep, Physical Activity Level, Stress Level, BMI Category, Blood Pressure, Heart Rate, Daily Steps, Sleep Disorder]
# Index: []

# %%
# TODO: Using that same categorical column, group by that column and find how
# many rows belong to each of the groups
df.groupby('Quality of Sleep').size()
# Out:
# Quality of Sleep
# 4      5
# 5      7
# 6    105
# 7     77
# 8    109
# 9     71
# dtype: int64

# %% [markdown]
# Determine which group shows up the least and which shows up the most:

# %% [markdown]
# ## NumPy

# %% [markdown]
# ### Exercise 6 NumPy Operations

# %%
# TODO: Choose two numeric columns and put them into a list variable
random_list = ['Quality of Sleep', 'Sleep Duration']

# %%
# TODO: Convert those columns into a numpy matrix (ndarray)
df[random_list].to_numpy()
# Out:
# array([[6. , 6.1],
#        [6. , 6.2],
#        [6. , 6.2],
#        [4. , 5.9],
#        [4. , 5.9],
#        [4. , 5.9],
#        [6. , 6.3],
#        [7. , 7.8],
#        [7. , 7.8],
#        [7. , 7.8],
#        [6. , 6.1],
#        [7. , 7.8],
#        [6. , 6.1],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6. ],
#        [5. , 6.5],
#        [6. , 6. ],
#        [5. , 6.5],
#        [7. , 7.6],
#        [7. , 7.7],
#        [7. , 7.7],
#        [7. , 7.7],
#        [7. , 7.7],
#        [7. , 7.8],
#        [7. , 7.9],
#        [7. , 7.8],
#        [7. , 7.9],
#        [7. , 7.9],
#        [7. , 7.9],
#        [5. , 6.4],
#        [5. , 6.4],
#        [8. , 7.9],
#        [6. , 6.1],
#        [7. , 7.7],
#        [6. , 6.1],
#        [6. , 6.1],
#        [7. , 7.6],
#        [7. , 7.6],
#        [7. , 7.6],
#        [7. , 7.7],
#        [7. , 7.7],
#        [7. , 7.7],
#        [7. , 7.8],
#        [7. , 7.7],
#        [7. , 7.8],
#        [7. , 7.7],
#        [7. , 7.8],
#        [7. , 7.7],
#        [7. , 7.7],
#        [8. , 7.5],
#        [8. , 7.5],
#        [6. , 6. ],
#        [7. , 7.6],
#        [6. , 6. ],
#        [6. , 6. ],
#        [7. , 7.7],
#        [6. , 6. ],
#        [6. , 6. ],
#        [7. , 7.7],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6.2],
#        [6. , 6.2],
#        [6. , 6.2],
#        [6. , 6.2],
#        [8. , 7.2],
#        [6. , 6. ],
#        [6. , 6.2],
#        [6. , 6.2],
#        [6. , 6.1],
#        [6. , 6.1],
#        [6. , 6.1],
#        [6. , 6.1],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6. ],
#        [4. , 5.8],
#        [4. , 5.8],
#        [7. , 6.7],
#        [7. , 6.7],
#        [8. , 7.5],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.3],
#        [8. , 7.3],
#        [8. , 7.3],
#        [8. , 7.3],
#        [8. , 7.5],
#        [7. , 7.4],
#        [8. , 7.2],
#        [8. , 7.1],
#        [8. , 7.2],
#        [8. , 7.1],
#        [8. , 7.1],
#        [8. , 7.1],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [5. , 6.6],
#        [8. , 7.2],
#        [5. , 6.6],
#        [6. , 6.1],
#        [8. , 7.8],
#        [8. , 7.8],
#        [8. , 7.4],
#        [8. , 7.2],
#        [8. , 7.4],
#        [8. , 7.2],
#        [8. , 7.4],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.5],
#        [8. , 7.3],
#        [8. , 7.1],
#        [8. , 7.3],
#        [8. , 7.3],
#        [8. , 7.1],
#        [8. , 7.3],
#        [8. , 7.3],
#        [8. , 7.1],
#        [8. , 7.3],
#        [8. , 7.3],
#        [8. , 7.1],
#        [8. , 7.1],
#        [8. , 7.1],
#        [8. , 7.1],
#        [8. , 7.1],
#        [8. , 7.1],
#        [8. , 7.1],
#        [8. , 7.1],
#        [8. , 7.1],
#        [7. , 7.4],
#        [8. , 7.2],
#        [5. , 6.5],
#        [7. , 6.9],
#        [9. , 8. ],
#        [9. , 8. ],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.2],
#        [8. , 7.9],
#        [8. , 7.9],
#        [8. , 7.6],
#        [8. , 7.3],
#        [7. , 7.1],
#        [7. , 7.1],
#        [8. , 7.7],
#        [8. , 7.7],
#        [8. , 7.7],
#        [8. , 7.7],
#        [8. , 7.7],
#        [8. , 7.6],
#        [8. , 7.6],
#        [8. , 7.6],
#        [6. , 6.5],
#        [8. , 7.8],
#        [8. , 7.8],
#        [8. , 7.8],
#        [8. , 7.8],
#        [8. , 7.8],
#        [8. , 7.8],
#        [6. , 6.8],
#        [6. , 6.8],
#        [7. , 6.7],
#        [6. , 6.3],
#        [7. , 6.7],
#        [6. , 6.5],
#        [7. , 6.7],
#        [6. , 6.4],
#        [6. , 6.5],
#        [6. , 6.5],
#        [6. , 6.5],
#        [6. , 6.5],
#        [6. , 6.5],
#        [6. , 6.5],
#        [6. , 6.5],
#        [6. , 6.5],
#        [6. , 6.5],
#        [8. , 7.8],
#        [8. , 7.8],
#        [6. , 6.9],
#        [8. , 7.6],
#        [8. , 7.7],
#        [8. , 7.7],
#        [8. , 7.7],
#        [8. , 7.7],
#        [8. , 7.8],
#        [8. , 7.7],
#        [8. , 7.8],
#        [8. , 7.8],
#        [8. , 7.8],
#        [8. , 7.8],
#        [8. , 7.8],
#        [8. , 7.8],
#        [8. , 7.8],
#        [8. , 7.8],
#        [6. , 6.5],
#        [7. , 6.6],
#        [6. , 6.4],
#        [6. , 6.3],
#        [6. , 6.4],
#        [7. , 6.6],
#        [6. , 6.3],
#        [7. , 6.6],
#        [6. , 6.3],
#        [7. , 6.6],
#        [6. , 6.3],
#        [7. , 6.6],
#        [6. , 6.3],
#        [7. , 6.6],
#        [6. , 6.3],
#        [7. , 6.6],
#        [6. , 6.3],
#        [6. , 6.4],
#        [7. , 6.5],
#        [6. , 6.3],
#        [6. , 6.4],
#        [7. , 6.5],
#        [6. , 6.3],
#        [6. , 6.4],
#        [7. , 6.5],
#        [6. , 6.3],
#        [7. , 6.5],
#        [6. , 6.3],
#        [7. , 6.8],
#        [6. , 6.4],
#        [6. , 6.5],
#        [7. , 6.8],
#        [7. , 6.8],
#        [7. , 6.5],
#        [7. , 6.5],
#        [7. , 6.5],
#        [7. , 6.5],
#        [7. , 6.6],
#        [7. , 6.6],
#        [7. , 6.6],
#        [7. , 6.6],
#        [7. , 6.6],
#        [7. , 6.6],
#        [7. , 6.6],
#        [7. , 6.9],
#        [7. , 7.3],
#        [6. , 5.9],
#        [7. , 7.3],
#        [6. , 6.2],
#        [6. , 6. ],
#        [6. , 6.1],
#        [6. , 6.1],
#        [6. , 6.1],
#        [6. , 6.1],
#        [6. , 6.2],
#        [6. , 6.2],
#        [6. , 6.2],
#        [9. , 8.1],
#        [9. , 8.1],
#        [6. , 6.1],
#        [9. , 8.3],
#        [6. , 6. ],
#        [6. , 6.1],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6. ],
#        [6. , 6.1],
#        [6. , 6. ],
#        [6. , 6.1],
#        [6. , 6.1],
#        [6. , 6. ],
#        [6. , 6.1],
#        [6. , 6. ],
#        [6. , 6.1],
#        [6. , 6.1],
#        [9. , 8.5],
#        [9. , 8.5],
#        [9. , 8.5],
#        [9. , 8.5],
#        [7. , 7.1],
#        [6. , 6. ],
#        [6. , 6.1],
#        [6. , 6.1],
#        [7. , 6.5],
#        [7. , 6.5],
#        [7. , 6.6],
#        [7. , 6.6],
#        [7. , 6.6],
#        [7. , 6.6],
#        [9. , 8.4],
#        [9. , 8.4],
#        [9. , 8.4],
#        [9. , 8.3],
#        [9. , 8.5],
#        [9. , 8.5],
#        [9. , 8.4],
#        [9. , 8.4],
#        [9. , 8.5],
#        [9. , 8.4],
#        [9. , 8.4],
#        [9. , 8.5],
#        [9. , 8.3],
#        [9. , 8.5],
#        [9. , 8.3],
#        [9. , 8.5],
#        [9. , 8.3],
#        [9. , 8.5],
#        [9. , 8.5],
#        [9. , 8.4],
#        [9. , 8.4],
#        [9. , 8.4],
#        [9. , 8.4],
#        [9. , 8.4],
#        [9. , 8.4],
#        [9. , 8.4],
#        [9. , 8.5],
#        [9. , 8.1],
#        [9. , 8.1],
#        [9. , 8.2],
#        [9. , 8.2],
#        [9. , 8.1],
#        [9. , 8.2],
#        [9. , 8.2],
#        [9. , 8.2],
#        [9. , 8.2],
#        [9. , 8.2],
#        [9. , 8.1],
#        [9. , 8.1],
#        [9. , 8.1],
#        [9. , 8. ],
#        [9. , 8. ],
#        [9. , 8. ],
#        [9. , 8. ],
#        [9. , 8. ],
#        [9. , 8. ],
#        [9. , 8. ],
#        [9. , 8.1],
#        [9. , 8.2],
#        [9. , 8.2],
#        [9. , 8.2],
#        [9. , 8.2],
#        [9. , 8. ],
#        [9. , 8. ],
#        [9. , 8.1],
#        [9. , 8. ],
#        [9. , 8.1],
#        [9. , 8.1],
#        [9. , 8. ],
#        [9. , 8.1],
#        [9. , 8.1],
#        [9. , 8.1]])

# %%
# TODO: Print the shape of the data
df[random_list].shape
# Out:
# (374, 2)

# %% [markdown]
# ### Exercise 7: More Statistics

# %%
# TODO: Compute the mean of each columns (axis = 0)
df[random_list].mean(axis=0)
# Out:
# Quality of Sleep    7.312834
# Sleep Duration      7.132086
# dtype: float64

# %%
# TODO: Compute the standard deviation of the columns
df[random_list].std(axis=0)
# Out:
# Quality of Sleep    1.196956
# Sleep Duration      0.795657
# dtype: float64

# %%
# TODO: Compute the mean of each row (axis = 1)
df[random_list].mean(axis=1)
# Out:
# 0      6.05
# 1      6.10
# 2      6.10
# 3      4.95
# 4      4.95
#        ...
# 369    8.55
# 370    8.50
# 371    8.55
# 372    8.55
# 373    8.55
# Length: 374, dtype: float64

# %%
# TODO: Compute the std deviation of each row
df[random_list].std(axis=1)
# Out:
# 0      0.070711
# 1      0.141421
# 2      0.141421
# 3      1.343503
# 4      1.343503
#          ...
# 369    0.636396
# 370    0.707107
# 371    0.636396
# 372    0.636396
# 373    0.636396
# Length: 374, dtype: float64

# %% [markdown]
# ### Exercise 8: Math Operations

# %%
# TODO: Calculate the dot product of the two original columns (you can think of these columns as vectors)
np.dot(df[random_list[0]], df[random_list[1]])
# Out:
# np.float64(19820.000000000007)

# %%
# TODO: Calculate the magnitude of both columns
np.linalg.norm(df[random_list[0]])
np.linalg.norm(df[random_list[1]])
# Out:
# np.float64(138.7813388031691)

# %%
# TODO: Find the cosine similarity (dot product / product of magnitudes)
np.dot(df[random_list[0]], df[random_list[1]]) / (np.linalg.norm(df[random_list[0]]) * np.linalg.norm(df[random_list[1]]))
# Out:
# np.float64(0.9966099615178343)

# %% [markdown]
# The cosine similarity is used to determine how related two features are to each other. A high value indicates that these features are highly correlated which means that changes in one variable corresponds to changes in the other. This is called **collinearity**.
#
# Using two or more highly correlated features in a machine learning algorithm can lead to numerous problems such as redundant information and reduced model reliability

# %% [markdown]
# ### Exercise 9: Further Analysis

# %% [markdown]
# #### Continue exploring and gaining more insights into your data. Utilize the docs linked above.
