# %% [markdown]
# <a href="https://colab.research.google.com/github/AnikaRanjan/MDST/blob/main/week2_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualizations
#
# ### **All exercises will be using your chosen dataset**

# %% [markdown]
# ## Step 1: Import your dataset using the tutorial from the slides

# %% [markdown]
# ## Step 2: Install necessary libraries. New libraries are Matplotlib and Seaborn for week 2. We will also use scikit-learn for Principal Component Analysis.

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Using scikit learn's diabetes dataset for the solutions
from sklearn.datasets import load_diabetes

# Load the diabetes dataset
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Sleep_health_and_lifestyle_dataset.csv')
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Exercises
#
# ### Documentation for Reference
#
# #### [Pandas](https://pandas.pydata.org/docs/)
#
# #### [NumPy](https://numpy.org/devdocs/)
#
# #### [Matplotlib](https://matplotlib.org/stable/)
#
# #### [Seaborn](https://seaborn.pydata.org/)
#
# #### [Scikit-Learn PCA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html)

# %% [markdown]
# In Machine Learning, the target **y** is the variable that the model is trying to predict given a set of features **X**. In regression tasks, **y** is a numerical value and in classification, it is a categorical value. Identify the target variable that you are using and state what type it is.

# %% [markdown]
# ### Exercise 1: Correlations

# %%
# TODO: Read dataset into a Pandas dataframe

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Sleep_health_and_lifestyle_dataset.csv')
df
# Out:
#      Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0       NaN   27             6.1                 6                       42
# 1       NaN   28             6.2                 6                       60
# 2       NaN   28             6.2                 6                       60
# 3       NaN   28             5.9                 4                       30
# 4       NaN   28             5.9                 4                       30
# ..      ...  ...             ...               ...                      ...
# 369     NaN   59             8.1                 9                       75
# 370     NaN   59             8.0                 9                       75
# 371     NaN   59             8.1                 9                       75
# 372     NaN   59             8.1                 9                       75
# 373     NaN   59             8.1                 9                       75
#
#      Stress Level  Heart Rate  Daily Steps  Sleep Disorder
# 0               6          77         4200             NaN
# 1               8          75        10000             NaN
# 2               8          75        10000             NaN
# 3               8          85         3000             NaN
# 4               8          85         3000             NaN
# ..            ...         ...          ...             ...
# 369             3          68         7000             NaN
# 370             3          68         7000             NaN
# 371             3          68         7000             NaN
# 372             3          68         7000             NaN
# 373             3          68         7000             NaN
#
# [374 rows x 9 columns]

# %%
# TODO: Create a correlation matrix heatmap (you first need to use df.corr()). Use sns for visualizing the heatmap)
# Keep in mind that these correlations highlight linear relationships between variables

# df.to_csv("/content/drive/MyDrive/Colab Notebooks/Sleep_health_and_lifestyle_dataset.csv", index=False)
# df

df['Sleep Disorder'].fillna(0, inplace=True)
# df.head(15)
# df.nunique()
# #df['Sleep Disorder'] = df['Sleep Disorder'].map({'None':0, 'Sleep Apnea': 1, 'Insomnia': 2})
# df.head(15)
# num = df.select_dtypes(include=['number'])
# num.head(15)
df['Sleep Disorder'] = df['Sleep Disorder'].replace("Insomnia", 2, inplace=True)
df['Sleep Disorder'] = df['Sleep Disorder'].replace("Sleep Apnea", 1, inplace=True)
df['Gender'] = df['Gender'].replace("Male", 1, inplace=True)
df['Gender'] = df['Gender'].replace("Female", 0, inplace=True)
df.head(15)

# df.drop(columns=['Person ID', 'Blood Pressure', 'BMI Category', 'Occupation'], inplace=True, axis=1)

# plt.figure(figsize=(8, 6))
# sns.heatmap(num.corr(), annot=True, cmap="coolwarm", center=0)
# plt.show()
# Out:
# /tmp/ipython-input-1879686496.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sleep Disorder'].fillna(0, inplace=True)
# /tmp/ipython-input-1879686496.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Sleep Disorder'].fillna(0, inplace=True)
# /tmp/ipython-input-1879686496.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sleep Disorder'] = df['Sleep Disorder'].replace("Sleep Apnea", 1, inplace=True)
# /tmp/ipython-input-1879686496.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'] = df['Gender'].replace("Male", 1, inplace=True)
# /tmp/ipython-input-1879686496.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'] = df['Gender'].replace("Female", 0, inplace=True)
#    Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0    None   27             6.1                 6                       42
# 1    None   28             6.2                 6                       60
# 2    None   28             6.2                 6                       60
# 3    None   28             5.9                 4                       30
# 4    None   28             5.9                 4                       30
# 5    None   28             5.9                 4                       30
# 6    None   29             6.3                 6                       40
# 7    None   29             7.8                 7                       75
# 8    None   29             7.8                 7                       75
# 9    None   29             7.8                 7                       75
# 10   None   29             6.1                 6                       30
# 11   None   29             7.8                 7                       75
# 12   None   29             6.1                 6                       30
# 13   None   29             6.0                 6                       30
# 14   None   29             6.0                 6                       30
#
#     Stress Level  Heart Rate  Daily Steps Sleep Disorder
# 0              6          77         4200           None
# 1              8          75        10000           None
# 2              8          75        10000           None
# 3              8          85         3000           None
# 4              8          85         3000           None
# 5              8          85         3000           None
# 6              7          82         3500           None
# 7              6          70         8000           None
# 8              6          70         8000           None
# 9              6          70         8000           None
# 10             8          70         8000           None
# 11             6          70         8000           None
# 12             8          70         8000           None
# 13             8          70         8000           None
# 14             8          70         8000           None

# %%
# TODO: Plot a histogram of the correlations of all features related to the desired target variable.
# Use matrix["target"] and matplotlib's plt.hist() for the histogram

matrix = df.corr()
plt.figure(figsize=(10, 8))
plt.hist(matrix["Sleep Disorder"])
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py:7065: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py:7066: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-923520987.py in <cell line: 0>()
#       4 matrix = df.corr()
#       5 plt.figure(figsize=(10, 8))
# ----> 6 plt.hist(matrix["Sleep Disorder"])
#       7 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3467     BarContainer | Polygon | list[BarContainer | Polygon],
#    3468 ]:
# -> 3469     return gca().hist(
#    3470         x,
#    3471         bins=bins,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7091             # this will automatically overwrite bins,
#    7092             # so that each histogram uses the same bins
# -> 7093             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7094             tops.append(m)
#    7095         tops = np.array(tops, float)  # causes problems later if it's an int
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py in histogram(a, bins, range, density, weights)
#     788     a, weights = _ravel_and_check_weights(a, weights)
#     789
# --> 790     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     791
#     792     # Histogram is an integer or a float array depending on the weights.
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py in _get_bin_edges(a, bins, range, weights)
#     426             raise ValueError('`bins` must be positive, when an integer')
#     427
# --> 428         first_edge, last_edge = _get_outer_edges(a, range)
#     429
#     430     elif np.ndim(bins) == 1:
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_histograms_impl.py in _get_outer_edges(a, range)
#     321         first_edge, last_edge = a.min(), a.max()
#     322         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 323             raise ValueError(
#     324                 "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     325
#
# ValueError: autodetected range of [nan, nan] is not finite

# %% [markdown]
# Which feature(s) are highly correlated to the target?
# **BMI**

# %% [markdown]
# ### Exercise 2: Numerical Feature Visualizations

# %%
# TODO: Identify one numerical feature to work with and plot a distribution of this feature using plt.hist() or sns.histplot().
# Also, use plt.title() to name the graph
plt.title("Distribution of BMI")
plt.hist(df["bmi"])
plt.show()

# %%
# TODO: Plot an ECDF graph using seaborn - sns.ecdfplot(). Ths stands for Empirical Cumulative Distribution function.
sns.ecdfplot(df["bmi"])
plt.show()

# %% [markdown]
# How is the feature distributed? A **uniform distribution** means that the **histogram** is level and the **ECDF** is a straight line. If possible, identify anything that might hint at bias in the sampling of this data such as abnormally high or abnormally low values that are present in the distribution.
#
# **BMI is right-skewed.**

# %% [markdown]
# ### Exercise 3: Categorical Feature Visualizations

# %%
# TODO: Identify one categorical feature to work with and plot a distribution of it using sns.countplot().
# If you don't have aa categorical variable, you can use pd.cut() to create one
df['bmi_categories'] = pd.cut(df['bmi'], bins=[-1, 0, 0.1, 1], labels=['underweight', 'normal', 'overweight'])

sns.countplot(data=df, x='bmi_categories')

# %% [markdown]
# Same as before, determine how the categories are distributed and highlight any biases that seem present.
#
# **A lot less overweight individuals than underweight or normal.**

# %% [markdown]
# ### Exercise 4: Target vs. Numerical Feature

# %% [markdown]
# #### Use the previous numerical feature and the chosen target to create the following visualizations.

# %% [markdown]
# **Do these exercises if your target is numerical**

# %%
# TODO: Create a seaborn or matplotlib scatterplot plot (scatterplot()) which shows a graphical relationship between these two variables.
sns.scatterplot(data=df, x='bmi', y='target')

# %%
# TODO: Create a matplotlib scatter plot (pyplot.scatter()). Use plt.xlabel and plt.ylabel
plt.scatter(df['bmi'], df['target'])
plt.xlabel('BMI')
plt.ylabel('target')
plt.show()

# %%
# TODO: Create a seaborn lmplot() which creates a regression line for the the scattered data
sns.lmplot(data=df, x='bmi', y='target')

# %% [markdown]
# Write down insights into how these variables are related (or not).
#
# **There is a noticable relationship between these two variables. As BMI increases, the target also increases. Although, there is a lot of variance in the target variable that the linear model from the lmplot() does not explain.**

# %% [markdown]
# **Do these exercises if your target is categorical**

# %%
# TODO: Create a seaborn boxplot() for the two variables

# sns.boxplot(data=df, x='feature', y='target_categorical')

# %%
# TODO: Create a seaborn violinplot() which shows the distribution of the numerical data

# sns.violinplot(data=df, x='feature', y='target_categorical')

# %% [markdown]
# Write down insights into how these variables are related (or not).

# %% [markdown]
# ### Exercise 5: Target vs. Categorical Feature

# %% [markdown]
# #### Use the previous categorical feature  and the chosen target to create the following visualizations.

# %% [markdown]
# **Do these exercises if your target is numerical**

# %%
# TODO: Create a seaborn boxplot() for these two variables
sns.boxplot(data=df, x='bmi_categories', y='target')

# %%
# TODO: Create a seaborn violinplot(). Use inner="quartile" to view the percentiles of the distribution
sns.violinplot(data=df, x='bmi_categories', y='target', inner="quartile")

# %% [markdown]
# Write down insights into how these variables are related (or not).

# %% [markdown]
# **Do these exercises if your target is categorical**

# %%
# TODO: Use pd.crosstab() which creates a frequency table of the categorical variables

# cross = pd.crosstab(df['bmi_categories'], df['target_categorical'])

# %%
# TODO: Using the crosstab above, create a seaborn heatmap() which visualizes this relationship

# sns.heatmap(cross, annot=True)

# %% [markdown]
# Write down insights into how these variables are related (or not).

# %% [markdown]
# ### Exercise 6: Principal Component Analysis

# %% [markdown]
# Principal Component Analysis is a powerful tool mainly used for dimensionality reduction by transforming the data into principal components (uncorrelated features) which are combinations of the original features in the data. In our case, we will be using it to create a 2d visualization of the data we are using.

# %%
# TODO: Use pandas to drop the target variable and put this into a variable X_data.

# dropping bmi categories since it is redundant
X_data = X_data = df.drop(columns = ['target', 'bmi_categories'])

# %% [markdown]
# Before doing PCA, we need to encode the categorical variables. One way of doing this is one-hot encoding which turns the variables into numerical 1's and 0's for the algorithm to understand.

# %%
# TODO: get_dummies is one-hot encoding the categorical variables
# Also, put the target varible into the y_data variable

X_data = pd.get_dummies(X_data, drop_first = True)
y_data = df['target']

# %%
# TODO: This makes sure all features contribute equally for the analysis

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_data)

# %%
# TODO: The first line initializes the pca algorithm.
# the second line creates the principal components

pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# We can determine how many PCs we need based on a variance explanation threshold. We do this by plotting a cumulative density plot of explained variance.

# %%
# TODO: Use plt.plot() to plot 'np.cumsum(pca.explained_variance_ratio_)'
plt.plot(np.cumsum(pca.explained_variance_ratio_))

# %% [markdown]
# The y-axis is the variance (the spread) of the original data. How many principal components are needed to explain ~90% of the variance in your data?
#
# **6 principal components explain about 90% of the variance in the features.**

# %%
# TODO: These lines are for graphing first two principal components

pca = PCA(n_components = 2)
X_pca = pca.fit_transform(X_scaled)

# %%
# TODO: This code creates a scatterplot of the first two principal components using sns.scatterplot().

df_pca = pd.DataFrame(X_pca)
df_pca["target"] = y_data
sns.scatterplot(data=df_pca, x=0, y=1, hue='target')

# %% [markdown]
# The x-axis is the first PC and the y-axis is the second PC. If your target was categorical, Identify if the clusters between the categories are noticeable. If your target was numerical, determine if the color gradient varies smoothly along the principal components. Note that points that are close together have similar data profiles.

# %% [markdown]
# This last line of code gives us the features that were involved in the first principal component. Note that the first principal component is designed to capture the maximum possible variance.

# %%
# Define the loadings for each feature on each Principal Component (the correlations of each feature in PC)
loadings = pd.DataFrame(
    pca.components_.T,
    index=X_data.columns,
    columns=[f"PC{i+1}" for i in range(pca.n_components_)]
)

# Show the top-contributing features for PC1
loadings["PC1"].sort_values(ascending=False).head(10)

# %% [markdown]
# What is the highest correlated feature in PC1?
#
# **s4**

# %% [markdown]
# ### Exercise 7: Further Visualizations

# %% [markdown]
# #### Continue creating data visualizations for other other features and further understand your data! Utilize the documentation.
